# %% [markdown]
# <a href="https://colab.research.google.com/github/duyguaran/deep-learning-examples/blob/main/ANN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.activity.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fexperimentsandconfigs%20https%3a%2f%2fwww.googleapis.com%2fauth%2fphotos.native&response_type=code
#
# Enter your authorization code:
# 4/1AY0e-g65KfbM4AsZ06TJ8EbQW6Yj0Qkt8waKWfJY-NurynBdrwCvMgmbKSE
# Mounted at /content/drive

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import cv2 
import os 
from random import shuffle 
from tqdm import tqdm 
import warnings
warnings.filterwarnings('ignore')
from PIL import Image

# %%
train_messy = "/content/drive/MyDrive/kaggle/images/train/messy"
train_clean= "/content/drive/MyDrive/kaggle/images/train/clean"
test_messy= "/content/drive/MyDrive/kaggle/images/val/clean"
test_clean= "/content/drive/MyDrive/kaggle/images/val/messy"
image_size = 128

# %%
for image in tqdm(os.listdir(train_messy)): 
    path = os.path.join(train_messy, image)
    img = cv2.imread(path, cv2.IMREAD_GRAYSCALE) 
    img = cv2.resize(img, (image_size, image_size)).flatten()   
    np_img=np.asarray(img)
    
for image2 in tqdm(os.listdir(train_clean)): 
    path = os.path.join(train_clean, image2)
    img2 = cv2.imread(path, cv2.IMREAD_GRAYSCALE) 
    img2 = cv2.resize(img2, (image_size, image_size)).flatten() 
    np_img2=np.asarray(img2)

plt.figure(figsize=(10,10))
plt.subplot(1, 2, 1)
plt.imshow(np_img.reshape(image_size, image_size))
plt.axis('off')
plt.subplot(1, 2, 2)
plt.imshow(np_img2.reshape(image_size, image_size))
plt.axis('off')
plt.title("Messy and Clean Rooms in GrayScale")
# Out:
# 100%|██████████| 96/96 [00:26<00:00,  3.67it/s]
# 100%|██████████| 96/96 [00:29<00:00,  3.24it/s]
# Text(0.5, 1.0, 'Messy and Clean Rooms in GrayScale')

# %%
def train_data():
    train_data_messy = [] 
    train_data_clean=[]
    for image1 in tqdm(os.listdir(train_messy)): 
        path = os.path.join(train_messy, image)
        img1 = cv2.imread(path, cv2.IMREAD_GRAYSCALE) 
        img1 = cv2.resize(img1, (image_size, image_size))
        train_data_messy.append(img1) 
    for image2 in tqdm(os.listdir(train_clean)): 
        path = os.path.join(train_clean, image)
        img2 = cv2.imread(path, cv2.IMREAD_GRAYSCALE) 
        img2 = cv2.resize(img2, (image_size, image_size))
        train_data_clean.append(img2) 
    
    train_data= np.concatenate((np.asarray(train_data_messy),np.asarray(train_data_clean)),axis=0)
    return train_data

# %%
def test_data():
    test_data_messy = [] 
    test_data_clean=[]
    for image1 in tqdm(os.listdir(test_messy)): 
        path = os.path.join(test_messy, image1)
        img1 = cv2.imread(path, cv2.IMREAD_GRAYSCALE) 
        img1 = cv2.resize(img1, (image_size, image_size))
        test_data_messy.append(img1) 
    for image2 in tqdm(os.listdir(test_clean)): 
        path = os.path.join(test_clean, image2)
        img2 = cv2.imread(path, cv2.IMREAD_GRAYSCALE) 
        img2 = cv2.resize(img2, (image_size, image_size))
        test_data_clean.append(img2) 
    
    test_data= np.concatenate((np.asarray(test_data_messy),np.asarray(test_data_clean)),axis=0) 
    return test_data

# %%
train_data = train_data() 
test_data = test_data()
# Out:
# 100%|██████████| 96/96 [00:00<00:00, 158.31it/s]
# 100%|██████████| 96/96 [00:00<00:00, 165.33it/s]
# 100%|██████████| 10/10 [00:03<00:00,  3.32it/s]
# 100%|██████████| 10/10 [00:02<00:00,  3.34it/s]

# %%
x_data=np.concatenate((train_data,test_data),axis=0)
x_data = (x_data-np.min(x_data))/(np.max(x_data)-np.min(x_data))

# %%
z1 = np.zeros(96)
o1 = np.ones(96)
Y_train = np.concatenate((o1, z1), axis=0)
z = np.zeros(10)
o = np.ones(10)
Y_test = np.concatenate((o, z), axis=0)

# %%
y_data=np.concatenate((Y_train,Y_test),axis=0).reshape(x_data.shape[0],1)

# %%
print("X shape: " , x_data.shape)
print("Y shape: " , y_data.shape)
# Out:
# X shape:  (212, 128, 128)
# Y shape:  (212, 1)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.15, random_state=42)
number_of_train = x_train.shape[0]
number_of_test = x_test.shape[0]

# %%
x_train_flatten = x_train.reshape(number_of_train,x_train.shape[1]*x_train.shape[2])
x_test_flatten = x_test .reshape(number_of_test,x_test.shape[1]*x_test.shape[2])
print("X train flatten",x_train_flatten.shape)
print("X test flatten",x_test_flatten.shape)
# Out:
# X train flatten (180, 16384)
# X test flatten (32, 16384)

# %%
x_train = x_train_flatten.T
x_test = x_test_flatten.T
y_test = y_test.T
y_train = y_train.T
print("x train: ",x_train.shape)
print("x test: ",x_test.shape)
print("y train: ",y_train.shape)
print("y test: ",y_test.shape)
# Out:
# x train:  (16384, 180)
# x test:  (16384, 32)
# y train:  (1, 180)
# y test:  (1, 32)

# %%
def sigmoid(z):
    y_head = 1/(1+np.exp(-z))
    return y_head

# %% [markdown]
# ## **2 Layer**

# %%
def initialize_parameters_and_layer_sizes_NN(x_train, y_train):
    parameters = {"weight1": np.random.randn(3,x_train.shape[0]) * 0.1,
                  "bias1": np.zeros((3,1)),
                  "weight2": np.random.randn(y_train.shape[0],3) * 0.1,
                  "bias2": np.zeros((y_train.shape[0],1))}
    return parameters

# %%
def forward_propagation_NN(x_train, parameters):

    Z1 = np.dot(parameters["weight1"],x_train) +parameters["bias1"]
    A1 = np.tanh(Z1)
    Z2 = np.dot(parameters["weight2"],A1) + parameters["bias2"]
    A2 = sigmoid(Z2)

    cache = {"Z1": Z1,
             "A1": A1,
             "Z2": Z2,
             "A2": A2}
    
    return A2, cache

# %%
def compute_cost_NN(A2, Y, parameters):
    logprobs = np.multiply(np.log(A2),Y)
    cost = -np.sum(logprobs)/Y.shape[1]
    return cost

# %%
def backward_propagation_NN(parameters, cache, X, Y):

    dZ2 = cache["A2"]-Y
    dW2 = np.dot(dZ2,cache["A1"].T)/X.shape[1]
    db2 = np.sum(dZ2,axis =1,keepdims=True)/X.shape[1]
    dZ1 = np.dot(parameters["weight2"].T,dZ2)*(1 - np.power(cache["A1"], 2))
    dW1 = np.dot(dZ1,X.T)/X.shape[1]
    db1 = np.sum(dZ1,axis =1,keepdims=True)/X.shape[1]
    grads = {"dweight1": dW1,
             "dbias1": db1,
             "dweight2": dW2,
             "dbias2": db2}
    return grads

# %%
def update_parameters_NN(parameters, grads, learning_rate = 0.01):
    parameters = {"weight1": parameters["weight1"]-learning_rate*grads["dweight1"],
                  "bias1": parameters["bias1"]-learning_rate*grads["dbias1"],
                  "weight2": parameters["weight2"]-learning_rate*grads["dweight2"],
                  "bias2": parameters["bias2"]-learning_rate*grads["dbias2"]}
    
    return parameters

# %%
def predict_NN(parameters,x_test):
    # x_test is a input for forward propagation
    A2, cache = forward_propagation_NN(x_test,parameters)
    Y_prediction = np.zeros((1,x_test.shape[1]))
    # if z is bigger than 0.5, our prediction is sign one (y_head=1),
    # if z is smaller than 0.5, our prediction is sign zero (y_head=0),
    for i in range(A2.shape[1]):
        if A2[0,i]<= 0.5:
            Y_prediction[0,i] = 0
        else:
            Y_prediction[0,i] = 1

    return Y_prediction

# %%
def two_layer_neural_network(x_train, y_train,x_test,y_test, num_iterations):
    cost_list = []
    index_list = []
    #initialize parameters and layer sizes
    parameters = initialize_parameters_and_layer_sizes_NN(x_train, y_train)

    for i in range(0, num_iterations):
         # forward propagation
        A2, cache = forward_propagation_NN(x_train,parameters)
        # compute cost
        cost = compute_cost_NN(A2, y_train, parameters)
         # backward propagation
        grads = backward_propagation_NN(parameters, cache, x_train, y_train)
         # update parameters
        parameters = update_parameters_NN(parameters, grads)
        
        if i % 100 == 0:
            cost_list.append(cost)
            index_list.append(i)
            print ("Cost after iteration %i: %f" %(i, cost))
    plt.plot(index_list,cost_list)
    plt.xticks(index_list,rotation='vertical')
    plt.xlabel("Number of Iterarion")
    plt.ylabel("Cost")
    plt.show()
    
    # predict
    y_prediction_test = predict_NN(parameters,x_test)
    y_prediction_train = predict_NN(parameters,x_train)

    # Print train/test Errors
    print("train accuracy: {} %".format(100 - np.mean(np.abs(y_prediction_train - y_train)) * 100))
    print("test accuracy: {} %".format(100 - np.mean(np.abs(y_prediction_test - y_test)) * 100))
    return parameters

parameters = two_layer_neural_network(x_train, y_train,x_test,y_test, num_iterations=1000)
# Out:
# Cost after iteration 0: 0.395642
# Cost after iteration 100: 0.211071
# Cost after iteration 200: 0.151798
# Cost after iteration 300: 0.119870
# Cost after iteration 400: 0.101868
# Cost after iteration 500: 0.079530
# Cost after iteration 600: 0.068575
# Cost after iteration 700: 0.060546
# Cost after iteration 800: 0.045046
# Cost after iteration 900: 0.037683
# train accuracy: 100.0 %
# test accuracy: 100.0 %

# %% [markdown]
# # **L Layer**

# %%
x_train, x_test, y_train, y_test = x_train.T, x_test.T, y_train.T, y_test.T # before the keras

# %%
# Implementing with keras library
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_val_score
from keras.models import Sequential # initialize neural network library
from keras.layers import Dense # build our layers library
def build_classifier():
    classifier = Sequential() # initialize neural network
    classifier.add(Dense(units = 8, kernel_initializer = 'uniform', activation = 'relu', input_dim = x_train.shape[1]))
    classifier.add(Dense(units = 4, kernel_initializer = 'uniform', activation = 'relu'))
    classifier.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))
    classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
    return classifier
classifier = KerasClassifier(build_fn = build_classifier, epochs = 100)
accuracies = cross_val_score(estimator = classifier, X = x_train, y = y_train, cv = 3)
mean = accuracies.mean()
variance = accuracies.std()
print("Accuracy mean: "+ str(mean))
print("Accuracy variance: "+ str(variance))
# Out:
# Epoch 1/100
# 4/4 [==============================] - 14s 7ms/step - loss: 0.6927 - accuracy: 0.5508
# Epoch 2/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6777 - accuracy: 0.4883
# Epoch 3/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6498 - accuracy: 0.5238
# Epoch 4/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6217 - accuracy: 0.4894
# Epoch 5/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.5755 - accuracy: 0.5133
# Epoch 6/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.5397 - accuracy: 0.5060
# Epoch 7/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.5100 - accuracy: 0.5019
# Epoch 8/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.5141 - accuracy: 0.4560
# Epoch 9/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.4914 - accuracy: 0.4821
# Epoch 10/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.4544 - accuracy: 0.9487
# Epoch 11/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4146 - accuracy: 0.9592
# Epoch 12/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4139 - accuracy: 0.9560
# Epoch 13/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4444 - accuracy: 0.9394
# Epoch 14/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4277 - accuracy: 0.9508
# Epoch 15/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.4495 - accuracy: 0.9425
# Epoch 16/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4661 - accuracy: 0.9415
# Epoch 17/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4093 - accuracy: 0.9498
# Epoch 18/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4363 - accuracy: 0.9394
# Epoch 19/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.4052 - accuracy: 0.9560
# Epoch 20/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.4051 - accuracy: 0.9529
# Epoch 21/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.4305 - accuracy: 0.9498
# Epoch 22/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3862 - accuracy: 0.9550
# Epoch 23/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3799 - accuracy: 0.9581
# Epoch 24/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3711 - accuracy: 0.9456
# Epoch 25/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3619 - accuracy: 0.9581
# Epoch 26/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3869 - accuracy: 0.9500
# Epoch 27/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.3416 - accuracy: 0.9848
# Epoch 28/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3675 - accuracy: 0.9750
# Epoch 29/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.3654 - accuracy: 0.9671
# Epoch 30/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3525 - accuracy: 0.9796
# Epoch 31/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3255 - accuracy: 0.9879
# Epoch 32/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3354 - accuracy: 0.9767
# Epoch 33/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3308 - accuracy: 0.9892
# Epoch 34/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3625 - accuracy: 0.9767
# Epoch 35/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3609 - accuracy: 0.9798
# Epoch 36/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3606 - accuracy: 0.9767
# Epoch 37/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3459 - accuracy: 0.9767
# Epoch 38/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3541 - accuracy: 0.9852
# Epoch 39/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3113 - accuracy: 0.9881
# Epoch 40/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3438 - accuracy: 0.9852
# Epoch 41/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3394 - accuracy: 0.9852
# Epoch 42/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3274 - accuracy: 0.9860
# Epoch 43/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3522 - accuracy: 0.9852
# Epoch 44/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3189 - accuracy: 1.0000
# Epoch 45/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3473 - accuracy: 0.9946
# Epoch 46/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2955 - accuracy: 0.9946
# Epoch 47/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3104 - accuracy: 1.0000
# Epoch 48/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3256 - accuracy: 1.0000
# Epoch 49/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3074 - accuracy: 1.0000
# Epoch 50/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3093 - accuracy: 1.0000
# Epoch 51/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2986 - accuracy: 1.0000
# Epoch 52/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3084 - accuracy: 1.0000
# Epoch 53/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2992 - accuracy: 1.0000
# Epoch 54/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3213 - accuracy: 1.0000
# Epoch 55/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2986 - accuracy: 1.0000
# Epoch 56/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3305 - accuracy: 1.0000
# Epoch 57/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3097 - accuracy: 1.0000
# Epoch 58/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3166 - accuracy: 1.0000
# Epoch 59/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3119 - accuracy: 1.0000
# Epoch 60/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3216 - accuracy: 1.0000
# Epoch 61/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2809 - accuracy: 1.0000
# Epoch 62/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3090 - accuracy: 1.0000
# Epoch 63/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3270 - accuracy: 1.0000
# Epoch 64/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2943 - accuracy: 1.0000
# Epoch 65/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2944 - accuracy: 1.0000
# Epoch 66/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2926 - accuracy: 1.0000
# Epoch 67/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2607 - accuracy: 1.0000
# Epoch 68/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.2905 - accuracy: 1.0000
# Epoch 69/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2648 - accuracy: 1.0000
# Epoch 70/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2902 - accuracy: 1.0000
# Epoch 71/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2847 - accuracy: 1.0000
# Epoch 72/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3070 - accuracy: 1.0000
# Epoch 73/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2706 - accuracy: 1.0000
# Epoch 74/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2862 - accuracy: 1.0000
# Epoch 75/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2655 - accuracy: 1.0000
# Epoch 76/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2808 - accuracy: 1.0000
# Epoch 77/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3072 - accuracy: 1.0000
# Epoch 78/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.2764 - accuracy: 1.0000
# Epoch 79/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2933 - accuracy: 1.0000
# Epoch 80/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2772 - accuracy: 1.0000
# Epoch 81/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2633 - accuracy: 1.0000
# Epoch 82/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2700 - accuracy: 1.0000
# Epoch 83/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2694 - accuracy: 1.0000
# Epoch 84/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2555 - accuracy: 1.0000
# Epoch 85/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2775 - accuracy: 1.0000
# Epoch 86/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2687 - accuracy: 1.0000
# Epoch 87/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2725 - accuracy: 1.0000
# Epoch 88/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2496 - accuracy: 1.0000
# Epoch 89/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2546 - accuracy: 1.0000
# Epoch 90/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2600 - accuracy: 1.0000
# Epoch 91/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2665 - accuracy: 1.0000
# Epoch 92/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2765 - accuracy: 1.0000
# Epoch 93/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2597 - accuracy: 1.0000
# Epoch 94/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2829 - accuracy: 1.0000
# Epoch 95/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2609 - accuracy: 1.0000
# Epoch 96/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2600 - accuracy: 1.0000
# Epoch 97/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.2688 - accuracy: 1.0000
# Epoch 98/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2803 - accuracy: 1.0000
# Epoch 99/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2583 - accuracy: 1.0000
# Epoch 100/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2685 - accuracy: 1.0000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.4122 - accuracy: 0.9500
# Epoch 1/100
# 4/4 [==============================] - 1s 8ms/step - loss: 0.6914 - accuracy: 0.4715
# Epoch 2/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.6801 - accuracy: 0.4965
# Epoch 3/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6702 - accuracy: 0.4246
# Epoch 4/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6519 - accuracy: 0.4381
# Epoch 5/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6282 - accuracy: 0.4579
# Epoch 6/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.5903 - accuracy: 0.4892
# Epoch 7/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.5539 - accuracy: 0.5048
# Epoch 8/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.5391 - accuracy: 0.5769
# Epoch 9/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4928 - accuracy: 0.9415
# Epoch 10/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.4575 - accuracy: 0.9540
# Epoch 11/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4821 - accuracy: 0.9300
# Epoch 12/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4407 - accuracy: 0.9529
# Epoch 13/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4307 - accuracy: 0.9456
# Epoch 14/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.4776 - accuracy: 0.9300
# Epoch 15/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4123 - accuracy: 0.9592
# Epoch 16/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4329 - accuracy: 0.9498
# Epoch 17/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4308 - accuracy: 0.9269
# Epoch 18/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.4204 - accuracy: 0.9487
# Epoch 19/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4186 - accuracy: 0.9508
# Epoch 20/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.4165 - accuracy: 0.9508
# Epoch 21/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.4310 - accuracy: 0.9446
# Epoch 22/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4182 - accuracy: 0.9456
# Epoch 23/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.4370 - accuracy: 0.9206
# Epoch 24/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4408 - accuracy: 0.9383
# Epoch 25/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3550 - accuracy: 0.9623
# Epoch 26/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.4300 - accuracy: 0.9352
# Epoch 27/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3918 - accuracy: 0.9654
# Epoch 28/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3849 - accuracy: 0.9477
# Epoch 29/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3745 - accuracy: 0.9675
# Epoch 30/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.4053 - accuracy: 0.9404
# Epoch 31/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3853 - accuracy: 0.9487
# Epoch 32/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3853 - accuracy: 0.9498
# Epoch 33/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3923 - accuracy: 0.9446
# Epoch 34/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3455 - accuracy: 0.9550
# Epoch 35/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3468 - accuracy: 0.9446
# Epoch 36/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3606 - accuracy: 0.9475
# Epoch 37/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3513 - accuracy: 0.9469
# Epoch 38/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3715 - accuracy: 0.9585
# Epoch 39/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3497 - accuracy: 0.9731
# Epoch 40/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3694 - accuracy: 0.9408
# Epoch 41/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3472 - accuracy: 0.9744
# Epoch 42/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3431 - accuracy: 0.9619
# Epoch 43/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3238 - accuracy: 0.9733
# Epoch 44/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3137 - accuracy: 0.9827
# Epoch 45/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.3504 - accuracy: 0.9838
# Epoch 46/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3240 - accuracy: 0.9767
# Epoch 47/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3117 - accuracy: 0.9892
# Epoch 48/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.3359 - accuracy: 0.9881
# Epoch 49/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3232 - accuracy: 0.9713
# Epoch 50/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.3470 - accuracy: 0.9767
# Epoch 51/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3331 - accuracy: 0.9881
# Epoch 52/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3156 - accuracy: 0.9892
# Epoch 53/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3115 - accuracy: 0.9767
# Epoch 54/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3100 - accuracy: 0.9915
# Epoch 55/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3222 - accuracy: 0.9892
# Epoch 56/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3290 - accuracy: 0.9915
# Epoch 57/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3209 - accuracy: 0.9915
# Epoch 58/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3089 - accuracy: 0.9946
# Epoch 59/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.3016 - accuracy: 0.9852
# Epoch 60/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3051 - accuracy: 0.9852
# Epoch 61/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3077 - accuracy: 0.9967
# Epoch 62/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3172 - accuracy: 0.9852
# Epoch 63/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3280 - accuracy: 0.9915
# Epoch 64/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.3199 - accuracy: 0.9946
# Epoch 65/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.3116 - accuracy: 0.9915
# Epoch 66/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.2959 - accuracy: 0.9967
# Epoch 67/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3196 - accuracy: 0.9967
# Epoch 68/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.3102 - accuracy: 0.9915
# Epoch 69/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3009 - accuracy: 0.9915
# Epoch 70/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2977 - accuracy: 0.9946
# Epoch 71/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3305 - accuracy: 0.9852
# Epoch 72/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.3012 - accuracy: 0.9915
# Epoch 73/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3101 - accuracy: 0.9915
# Epoch 74/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.2816 - accuracy: 0.9852
# Epoch 75/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2810 - accuracy: 0.9915
# Epoch 76/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2931 - accuracy: 0.9915
# Epoch 77/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2991 - accuracy: 0.9946
# Epoch 78/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.2884 - accuracy: 0.9946
# Epoch 79/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2930 - accuracy: 0.9946
# Epoch 80/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3111 - accuracy: 0.9852
# Epoch 81/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2995 - accuracy: 0.9967
# Epoch 82/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2885 - accuracy: 0.9967
# Epoch 83/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2900 - accuracy: 0.9967
# Epoch 84/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2907 - accuracy: 0.9915
# Epoch 85/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2768 - accuracy: 0.9946
# Epoch 86/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2833 - accuracy: 0.9915
# Epoch 87/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2668 - accuracy: 0.9946
# Epoch 88/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.2753 - accuracy: 0.9946
# Epoch 89/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.2877 - accuracy: 0.9946
# Epoch 90/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.2985 - accuracy: 0.9852
# Epoch 91/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3029 - accuracy: 0.9852
# Epoch 92/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2714 - accuracy: 0.9852
# Epoch 93/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.2929 - accuracy: 0.9852
# Epoch 94/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2886 - accuracy: 0.9852
# Epoch 95/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2736 - accuracy: 0.9946
# Epoch 96/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2848 - accuracy: 0.9915
# Epoch 97/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2851 - accuracy: 0.9967
# Epoch 98/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2543 - accuracy: 0.9967
# Epoch 99/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2922 - accuracy: 0.9852
# Epoch 100/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2643 - accuracy: 0.9946
# 2/2 [==============================] - 0s 7ms/step - loss: 0.3434 - accuracy: 0.9167
# Epoch 1/100
# 4/4 [==============================] - 1s 7ms/step - loss: 0.6883 - accuracy: 0.4810
# Epoch 2/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6573 - accuracy: 0.4998
# Epoch 3/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6198 - accuracy: 0.4935
# Epoch 4/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.5851 - accuracy: 0.4769
# Epoch 5/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.5412 - accuracy: 0.4831
# Epoch 6/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.5003 - accuracy: 0.4935
# Epoch 7/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4636 - accuracy: 0.5133
# Epoch 8/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.4405 - accuracy: 0.9529
# Epoch 9/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.4571 - accuracy: 0.9383
# Epoch 10/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.4170 - accuracy: 0.9571
# Epoch 11/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.3933 - accuracy: 0.9581
# Epoch 12/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4593 - accuracy: 0.9321
# Epoch 13/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.4305 - accuracy: 0.9477
# Epoch 14/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4214 - accuracy: 0.9477
# Epoch 15/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4497 - accuracy: 0.9383
# Epoch 16/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4049 - accuracy: 0.9415
# Epoch 17/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3985 - accuracy: 0.9477
# Epoch 18/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3886 - accuracy: 0.9383
# Epoch 19/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3803 - accuracy: 0.9665
# Epoch 20/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3681 - accuracy: 0.9498
# Epoch 21/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3441 - accuracy: 0.9602
# Epoch 22/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3602 - accuracy: 0.9654
# Epoch 23/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.3694 - accuracy: 0.9477
# Epoch 24/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3509 - accuracy: 0.9477
# Epoch 25/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3479 - accuracy: 0.9394
# Epoch 26/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3567 - accuracy: 0.9540
# Epoch 27/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3667 - accuracy: 0.9479
# Epoch 28/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3501 - accuracy: 0.9502
# Epoch 29/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.3565 - accuracy: 0.9915
# Epoch 30/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3684 - accuracy: 1.0000
# Epoch 31/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3237 - accuracy: 1.0000
# Epoch 32/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3245 - accuracy: 1.0000
# Epoch 33/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3360 - accuracy: 1.0000
# Epoch 34/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3341 - accuracy: 1.0000
# Epoch 35/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3452 - accuracy: 1.0000
# Epoch 36/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3205 - accuracy: 0.9852
# Epoch 37/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3418 - accuracy: 1.0000
# Epoch 38/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3216 - accuracy: 1.0000
# Epoch 39/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3297 - accuracy: 1.0000
# Epoch 40/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3019 - accuracy: 0.9852
# Epoch 41/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3187 - accuracy: 1.0000
# Epoch 42/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3026 - accuracy: 1.0000
# Epoch 43/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3210 - accuracy: 1.0000
# Epoch 44/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3044 - accuracy: 1.0000
# Epoch 45/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2815 - accuracy: 1.0000
# Epoch 46/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3120 - accuracy: 1.0000
# Epoch 47/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3214 - accuracy: 1.0000
# Epoch 48/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3157 - accuracy: 1.0000
# Epoch 49/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3207 - accuracy: 1.0000
# Epoch 50/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3002 - accuracy: 1.0000
# Epoch 51/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3298 - accuracy: 1.0000
# Epoch 52/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3038 - accuracy: 1.0000
# Epoch 53/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3041 - accuracy: 1.0000
# Epoch 54/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2951 - accuracy: 1.0000
# Epoch 55/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2911 - accuracy: 1.0000
# Epoch 56/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3019 - accuracy: 1.0000
# Epoch 57/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3006 - accuracy: 1.0000
# Epoch 58/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2835 - accuracy: 1.0000
# Epoch 59/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3068 - accuracy: 1.0000
# Epoch 60/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2926 - accuracy: 1.0000
# Epoch 61/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3075 - accuracy: 1.0000
# Epoch 62/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3016 - accuracy: 1.0000
# Epoch 63/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3207 - accuracy: 1.0000
# Epoch 64/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3160 - accuracy: 1.0000
# Epoch 65/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2878 - accuracy: 1.0000
# Epoch 66/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2943 - accuracy: 1.0000
# Epoch 67/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2909 - accuracy: 1.0000
# Epoch 68/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.2711 - accuracy: 1.0000
# Epoch 69/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2764 - accuracy: 1.0000
# Epoch 70/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2835 - accuracy: 1.0000
# Epoch 71/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3101 - accuracy: 1.0000
# Epoch 72/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.2891 - accuracy: 1.0000
# Epoch 73/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2894 - accuracy: 1.0000
# Epoch 74/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3020 - accuracy: 1.0000
# Epoch 75/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2808 - accuracy: 1.0000
# Epoch 76/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3005 - accuracy: 1.0000
# Epoch 77/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2819 - accuracy: 1.0000
# Epoch 78/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3061 - accuracy: 1.0000
# Epoch 79/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2762 - accuracy: 1.0000
# Epoch 80/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2876 - accuracy: 1.0000
# Epoch 81/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2868 - accuracy: 1.0000
# Epoch 82/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2951 - accuracy: 1.0000
# Epoch 83/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.2982 - accuracy: 1.0000
# Epoch 84/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2786 - accuracy: 1.0000
# Epoch 85/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2747 - accuracy: 1.0000
# Epoch 86/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2810 - accuracy: 1.0000
# Epoch 87/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2598 - accuracy: 1.0000
# Epoch 88/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.2599 - accuracy: 1.0000
# Epoch 89/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.2801 - accuracy: 1.0000
# Epoch 90/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.2791 - accuracy: 1.0000
# Epoch 91/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2705 - accuracy: 1.0000
# Epoch 92/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2565 - accuracy: 1.0000
# Epoch 93/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2857 - accuracy: 1.0000
# Epoch 94/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2596 - accuracy: 1.0000
# Epoch 95/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2653 - accuracy: 1.0000
# Epoch 96/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2647 - accuracy: 1.0000
# Epoch 97/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2765 - accuracy: 1.0000
# Epoch 98/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.2771 - accuracy: 1.0000
# Epoch 99/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2391 - accuracy: 1.0000
# Epoch 100/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2363 - accuracy: 1.0000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.3701 - accuracy: 0.9333
# Accuracy mean: 0.9333333373069763
# Accuracy variance: 0.01360826337093179
